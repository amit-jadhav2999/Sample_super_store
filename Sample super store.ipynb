# %%
import pandas as pd

# %%
df = pd.read_csv("Sample - Superstore.csv", encoding='latin-1')

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# Data type
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
# Showing unique data in count 

df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %%
df.sort_values(by="Order Date",ascending=False)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 906      907  CA-2017-143259 2017-12-30   1/3/2018  Standard Class
# 907      908  CA-2017-143259 2017-12-30   1/3/2018  Standard Class
# 1296    1297  CA-2017-115427 2017-12-30   1/3/2018  Standard Class
# 1297    1298  CA-2017-115427 2017-12-30   1/3/2018  Standard Class
# 645      646  CA-2017-126221 2017-12-30   1/5/2018  Standard Class
# ...      ...             ...        ...        ...             ...
# 1759    1760  CA-2014-141817 2014-01-05  1/12/2014  Standard Class
# 741      742  CA-2014-112326 2014-01-04   1/8/2014  Standard Class
# 739      740  CA-2014-112326 2014-01-04   1/8/2014  Standard Class
# 740      741  CA-2014-112326 2014-01-04   1/8/2014  Standard Class
# 7980    7981  CA-2014-103800 2014-01-03   1/7/2014  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 906     PO-18865  Patrick O'Donnell     Consumer  United States
# ...

# %%
# To conver into date time

df["Order Date"]=pd.to_datetime(df["Order Date"])

# %%
df["Ship Date"]= pd.to_datetime(df["Ship Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df["Order Date"].unique
# Out:
# array(['11/8/2016', '6/12/2016', '10/11/2015', ..., '6/3/2016',
#        '4/12/2015', '1/21/2014'], dtype=object)

# %%
pd.to_datetime(df["Order Date"]).dt.year.unique()
# Out:
# array([2016, 2015, 2014, 2017], dtype=int64)

# %%
# Total sales 
df.columns
df["Sales"].sum()
# Out:
# 2297200.8603000003

# %%
# Profite 
df["Profit"].sum()
# Out:
# 286397.0217

# %%
# % Of profite

(df["Profit"].sum()/df["Sales"].sum()* 100).round(2)
# Out:
# 12.47

# %%
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %%
# City Hampton sales 

df.loc[df["City"]=="Hampton","Sales"].sum()
# Out:
# 2722.2599999999998

# %%
df.loc[df['City'] == 'Jupiter', 'Sales']
# Out:
# 5440    2.064
# Name: Sales, dtype: float64

# %%
# City wise Sales

df.groupby("City")["Sales"].sum()
# Out:
# City
# Aberdeen         25.500
# Abilene           1.392
# Akron          2729.986
# Albuquerque    2220.160
# Alexandria     5519.570
#                  ...
# Woonsocket      195.550
# Yonkers        7657.666
# York            817.978
# Yucaipa          50.800
# Yuma            840.865
# Name: Sales, Length: 531, dtype: float64

# %%
# State wise sales 

df.groupby("State")["Sales"].sum()
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
# sales as a region

df.groupby("Region")["Sales"].sum()
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
# sales as a sub-Category

df.groupby("Sub-Category")["Sales"].sum()
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
# Find max discount
df["Discount"].mean()
# Out:
# 0.15620272163297977

# %%
# filter data as per avg discount

df[df["Discount"] < df["Discount"].mean() ]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID    Customer Name    Segment        Country         City  ...  \
# 0       CG-12520      Claire Gute   Consumer  United States    Henderson  ...
# ...

# %%
df["Quantity"].max()
# Out:
# 14

# %%
# Which category qty is very large 

df[df["Quantity"] > df["Quantity"].max()-1]["Sub-Category"].value_counts()
# Out:
# Binders        5
# Furnishings    4
# Paper          4
# Chairs         4
# Phones         3
# Accessories    3
# Storage        2
# Fasteners      1
# Labels         1
# Appliances     1
# Art            1
# Name: Sub-Category, dtype: int64

# %%
# In catagory Max qty in one order   and sort by

df.groupby("Sub-Category")["Quantity"].max().sort_values(ascending = False)
# Out:
# Sub-Category
# Accessories    14
# Appliances     14
# Storage        14
# Phones         14
# Paper          14
# Labels         14
# Furnishings    14
# Fasteners      14
# Chairs         14
# Binders        14
# Art            14
# Bookcases      13
# Tables         13
# Machines       11
# Supplies       10
# Envelopes       9
# Copiers         9
# Name: Quantity, dtype: int64

# %%
# To find max Qty sales category

e = pd.DataFrame(  df.groupby("Sub-Category")["Quantity"].sum())
e.shape
#r = e["Quantity"].max()
e[e.Quantity ==e["Quantity"].max()]
# Out:
#               Quantity
# Sub-Category
# Binders           5974

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# find segment catogery 
df.nunu
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# How many customer 
df.nunique()["Order ID"]
# Out:
# array(['CA-2016-152156', 'CA-2016-138688', 'US-2015-108966', ...,
#        'CA-2014-110422', 'CA-2017-121258', 'CA-2017-119914'], dtype=object)

# %%
# which are the best customer name
df.groupby("Customer Name")["Sales"].sum()
d = pd.DataFrame(df.groupby("Customer Name")["Sales"].sum())

d[d.Sales == d["Sales"].max()]
# Out:
#                   Sales
# Customer Name
# Sean Miller    25043.05

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.loc[1]
# Out:
# Row ID                                                           2
# Order ID                                            CA-2016-152156
# Order Date                                               11/8/2016
# Ship Date                                               11/11/2016
# Ship Mode                                             Second Class
# Customer ID                                               CG-12520
# Customer Name                                          Claire Gute
# Segment                                                   Consumer
# Country                                              United States
# City                                                     Henderson
# State                                                     Kentucky
# Postal Code                                                  42420
# Region                                                       South
# Product ID                                         FUR-CH-10000454
# ...

# %%
pd.set_option('display.max.rows', 1350)
pd.set_option('display.max.columns', 15)

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name  ...         Category Sub-Category  \
# ...

# %%
# filter on category

df[df["Category"]=="Furniture"]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10        11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9962    9963  CA-2015-168088   3/19/2015   3/22/2015     First Class
# 9964    9965  CA-2016-146374   12/5/2016  12/10/2016    Second Class
# 9980    9981  US-2015-151435    9/6/2015    9/9/2015    Second Class
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 0       CG-12520       Claire Gute     Consumer  United States
# ...

# %%
# filter on more column (Segment) or Ship Date

df[(df["Segment"]=="Consumer") | (df['Ship Date']=="First Class")]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# 

df[(df["Segment"]=="Consumer") & (df['Ship Date']=="First Class")]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
# Loss and profir 
# condition  0 to 30 Profit to 65 average up no profite

df["Profit_Remarks"] = ["Profite"   if i >= 0.3 elif i <=0.3 or i >=65 else "No Profite"  for i df["Discount"] ]

# %%
set(df["Discount"])
# Out:
# {0.0, 0.1, 0.15, 0.2, 0.3, 0.32, 0.4, 0.45, 0.5, 0.6, 0.7, 0.8}

# %%
df1['new_Status'] = [ 'Solved'        if i == 'Closed' or i == 'Solved'  else 'Open'       for i in df1['Status'] ]

# %%
df["Profit_Remarks"] = ["Profit" if i >= 0.3 else "No Profit" if i <= 0.3 or i >= 0.65 else "AVG Profit" for i in df["Discount"]]

# %%
set(df["Profit_Remarks"])
# Out:
# {'Moderate Profit', 'No Profit', 'Profit'}

# %%
df["Profit_Remarks"] = ["No Profit" if  i >= 0.6 else "Profit"  for i in df["Discount"]]

# %%
df["Profit_Remarks"] = ["Profit" if 0 <= i <= 0.2 else "Moderate" if 0.2 < i <= 0.4 else "Average Profitr" if 0.4 < i <= 0.6 else "No Profite" for i in df["Discount"]]

# %%
df.groupby(["Profit_Remarks"])["Discount"].max().sort_values(ascending=True)
# Out:
# Profit_Remarks
# Profit             0.2
# Moderate           0.4
# Average Profitr    0.6
# No Profite         0.8
# Name: Discount, dtype: float64

# %%
df.groupby(["Profit_Remarks"])["Discount"].min()
# Out:
# Profit_Remarks
# Average Profitr    0.45
# Moderate           0.30
# No Profite         0.70
# Profit             0.00
# Name: Discount, dtype: float64
